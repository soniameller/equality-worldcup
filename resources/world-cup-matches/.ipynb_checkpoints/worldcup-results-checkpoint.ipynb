# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # World cup match results

# %%
men_worldcup_results = pd.read_csv('WorldCupMatches.csv')
women_worldcup_results = pd.read_csv('WomenWorldCupMatches.csv')

# %% [markdown]
# ## Men dataset cleanup

# %%
men_worldcup_results = worldcup_results.iloc[:852]

men_worldcup_results.insert(2, 'Gender', 'M')

men_worldcup_results[men_worldcup_results['Home Team Name'] =='Argentina']
# Out:
#        Year              Datetime Gender           Stage  \
# 4    1930.0  15 Jul 1930 - 16:00       M         Group 1
# 10   1930.0  19 Jul 1930 - 15:00       M         Group 1
# 14   1930.0  22 Jul 1930 - 14:45       M         Group 1
# 15   1930.0  26 Jul 1930 - 14:45       M     Semi-finals
# 103  1958.0  08 Jun 1958 - 19:00       M         Group 1
# 115  1958.0  11 Jun 1958 - 19:00       M         Group 1
# 138  1962.0  30 May 1962 - 15:00       M         Group 4
# 174  1966.0  13 Jul 1966 - 19:30       M         Group 2
# 185  1966.0  19 Jul 1966 - 19:30       M         Group 2
# 247  1974.0  19 Jun 1974 - 19:30       M         Group 4
# 253  1974.0  23 Jun 1974 - 16:00       M         Group 4
# 260  1974.0  30 Jun 1974 - 16:00       M         Group A
# 266  1974.0  03 Jul 1974 - 19:30       M         Group A
# 273  1978.0  02 Jun 1978 - 19:15       M         Group 1
# 281  1978.0  06 Jun 1978 - 19:15       M         Group 1
# 297  1978.0  14 Jun 1978 - 19:15       M         Group B
# 301  1978.0  18 Jun 1978 - 19:15       M         Group B
# 305  1978.0  21 Jun 1978 - 19:15       M         Group B
# 307  1978.0  25 Jun 1978 - 15:00       M           Final
# 308  1982.0  13 Jun 1982 - 20:00       M         Group 3
# 321  1982.0  18 Jun 1982 - 21:00       M         Group 3
# 336  1982.0  23 Jun 1982 - 21:00       M         Group 3
# 350  1982.0  02 Jul 1982 - 17:15       M         Group 3
# 364  1986.0  02 Jun 1986 - 12:00       M         Group A
# 387  1986.0  10 Jun 1986 - 12:00       M         Group A
# 398  1986.0  16 Jun 1986 - 16:00       M     Round of 16
# 407  1986.0  22 Jun 1986 - 12:00       M  Quarter-finals
# 409  1986.0  25 Jun 1986 - 16:00       M     Semi-finals
# 411  1986.0  29 Jun 1986 - 12:00       M           Final
# 412  1990.0  08 Jun 1990 - 18:00       M         Group B
# 424  1990.0  13 Jun 1990 - 21:00       M         Group B
# 436  1990.0  18 Jun 1990 - 21:00       M         Group B
# 474  1994.0  21 Jun 1994 - 12:30       M         Group D
# 486  1994.0  25 Jun 1994 - 16:00       M         Group D
# 499  1994.0  30 Jun 1994 - 19:30       M         Group D
# 526  1998.0  14 Jun 1998 - 14:30       M         Group H
# 544  1998.0  21 Jun 1998 - 17:30       M         Group H
# 561  1998.0  26 Jun 1998 - 16:00       M         Group H
# 571  1998.0  30 Jun 1998 - 21:00       M     Round of 16
# 584  2002.0  02 Jun 2002 - 14:30       M         Group F
# 601  2002.0  07 Jun 2002 - 20:30       M         Group F
# 648  2006.0  10 Jun 2006 - 21:00       M         Group C
# 664  2006.0  16 Jun 2006 - 15:00       M         Group C
# 693  2006.0  24 Jun 2006 - 21:00       M     Round of 16
# 711  2010.0  12 Jun 2010 - 16:00       M         Group B
# 725  2010.0  17 Jun 2010 - 13:30       M         Group B
# 759  2010.0  27 Jun 2010 - 20:30       M     Round of 16
# 766  2010.0  03 Jul 2010 - 16:00       M  Quarter-finals
# 782  2014.0  15 Jun 2014 - 19:00       M         Group F
# 798  2014.0  21 Jun 2014 - 13:00       M         Group F
# 831  2014.0  05 Jul 2014 - 13:00       M  Quarter-finals
# 834  2014.0  01 Jul 2014 - 13:00       M     Round of 16
# 842  2014.0  01 Jul 2014 - 13:00       M     Round of 16
# 846  2014.0  05 Jul 2014 - 13:00       M  Quarter-finals
#
#                                                Stadium             City  \
# 4                                       Parque Central      Montevideo
# 10                                  Estadio Centenario      Montevideo
# 14                                  Estadio Centenario      Montevideo
# 15                                  Estadio Centenario      Montevideo
# 103                                      Malmo Stadion           Malm�
# 115                                        Orjans Vall        Halmstad
# 138                        Estadio El Teniente-Codelco        Rancagua
# 174                                         Villa Park      Birmingham
# 185                                       Hillsborough       Sheffield
# 247                                      Neckarstadion       Stuttgart
# 253                                     Olympiastadion          Munich
# 260                               Niedersachsenstadion         Hanover
# 266                                        Parkstadion   Gelsenkirchen
# 273  El Monumental - Estadio Monumental Antonio Ves...    Buenos Aires
# 281  El Monumental - Estadio Monumental Antonio Ves...    Buenos Aires
# 297        Arroyito - Estadio Dr. Lisandro de la Torre         Rosario
# 301        Arroyito - Estadio Dr. Lisandro de la Torre         Rosario
# 305        Arroyito - Estadio Dr. Lisandro de la Torre         Rosario
# 307  El Monumental - Estadio Monumental Antonio Ves...    Buenos Aires
# 308                                           Camp Nou       Barcelona
# 321                                    Jose Rico Perez        Alicante
# 336                                    Jose Rico Perez        Alicante
# 350                                             Sarria       Barcelona
# 364                     Estadio Ol�mpico Universitario     Mexico City
# 387                     Estadio Ol�mpico Universitario     Mexico City
# 398                                         Cuauhtemoc          Puebla
# 407                                     Estadio Azteca     Mexico City
# 409                                     Estadio Azteca     Mexico City
# 411                                     Estadio Azteca     Mexico City
# 412                                    Giuseppe Meazza           Milan
# 424                                          San Paolo          Naples
# 436                                          San Paolo          Naples
# 474                                    Foxboro Stadium          Boston
# 486                                    Foxboro Stadium          Boston
# 499                                        Cotton Bowl          Dallas
# 526                                    Stade Municipal        Toulouse
# 544                                   Parc des Princes           Paris
# 561                              Stade du Parc Lescure        Bordeaux
# 571                            Stade Geoffroy Guichard   Saint-Etienne
# 584                                    Kashima Stadium         Ibaraki
# 601                                       Sapporo Dome         Sapporo
# 648                    FIFA World Cup Stadium, Hamburg         Hamburg
# 664              FIFA World Cup Stadium, Gelsenkirchen   Gelsenkirchen
# 693                                     Zentralstadion         Leipzig
# 711                                 Ellis Park Stadium    Johannesburg
# 725                                Soccer City Stadium    Johannesburg
# 759                                Soccer City Stadium    Johannesburg
# 766                                  Cape Town Stadium       Cape Town
# 782                                Estadio do Maracana  Rio De Janeiro
# 798                                   Estadio Mineirao  Belo Horizonte
# 831                                   Estadio Nacional        Brasilia
# 834                                 Arena de Sao Paulo       Sao Paulo
# 842                                 Arena de Sao Paulo       Sao Paulo
# 846                                   Estadio Nacional        Brasilia
#
#     Home Team Name  Home Team Goals  Away Team Goals  \
# 4        Argentina              1.0              0.0
# 10       Argentina              6.0              3.0
# 14       Argentina              3.0              1.0
# 15       Argentina              6.0              1.0
# 103      Argentina              1.0              3.0
# 115      Argentina              3.0              1.0
# 138      Argentina              1.0              0.0
# 174      Argentina              2.0              1.0
# 185      Argentina              2.0              0.0
# 247      Argentina              1.0              1.0
# 253      Argentina              4.0              1.0
# 260      Argentina              1.0              2.0
# 266      Argentina              1.0              1.0
# 273      Argentina              2.0              1.0
# 281      Argentina              2.0              1.0
# 297      Argentina              2.0              0.0
# 301      Argentina              0.0              0.0
# 305      Argentina              6.0              0.0
# 307      Argentina              3.0              1.0
# 308      Argentina              0.0              1.0
# 321      Argentina              4.0              1.0
# 336      Argentina              2.0              0.0
# 350      Argentina              1.0              3.0
# 364      Argentina              3.0              1.0
# 387      Argentina              2.0              0.0
# 398      Argentina              1.0              0.0
# 407      Argentina              2.0              1.0
# 409      Argentina              2.0              0.0
# 411      Argentina              3.0              2.0
# 412      Argentina              0.0              1.0
# 424      Argentina              2.0              0.0
# 436      Argentina              1.0              1.0
# 474      Argentina              4.0              0.0
# 486      Argentina              2.0              1.0
# 499      Argentina              0.0              2.0
# 526      Argentina              1.0              0.0
# 544      Argentina              5.0              0.0
# 561      Argentina              1.0              0.0
# 571      Argentina              2.0              2.0
# 584      Argentina              1.0              0.0
# 601      Argentina              0.0              1.0
# 648      Argentina              2.0              1.0
# 664      Argentina              6.0              0.0
# 693      Argentina              2.0              1.0
# 711      Argentina              1.0              0.0
# 725      Argentina              4.0              1.0
# 759      Argentina              3.0              1.0
# 766      Argentina              0.0              4.0
# 782      Argentina              2.0              1.0
# 798      Argentina              1.0              0.0
# 831      Argentina              1.0              0.0
# 834      Argentina              1.0              0.0
# 842      Argentina              1.0              0.0
# 846      Argentina              1.0              0.0
#
#                  Away Team Name  ... Attendance  Half-time Home Goals  \
# 4                        France  ...    23409.0                   0.0
# 10                       Mexico  ...    42100.0                   3.0
# 14                        Chile  ...    41459.0                   2.0
# 15                          USA  ...    72886.0                   1.0
# 103                  Germany FR  ...    31156.0                   1.0
# 115            Northern Ireland  ...    14174.0                   1.0
# 138                    Bulgaria  ...     7134.0                   1.0
# 174                       Spain  ...    42738.0                   0.0
# 185                 Switzerland  ...    32127.0                   0.0
# 247                       Italy  ...    70100.0                   1.0
# 253                       Haiti  ...    25900.0                   2.0
# 260                      Brazil  ...    39400.0                   1.0
# 266                   German DR  ...    54254.0                   1.0
# 273                     Hungary  ...    71615.0                   1.0
# 281                      France  ...    71666.0                   1.0
# 297                      Poland  ...    37091.0                   1.0
# 301                      Brazil  ...    37326.0                   0.0
# 305                        Peru  ...    37315.0                   2.0
# 307                 Netherlands  ...    71483.0                   0.0
# 308                     Belgium  ...    95000.0                   0.0
# 321                     Hungary  ...    32093.0                   2.0
# 336                 El Salvador  ...    32500.0                   1.0
# 350                      Brazil  ...    44000.0                   0.0
# 364              Korea Republic  ...    60000.0                   2.0
# 387                    Bulgaria  ...    65000.0                   1.0
# 398                     Uruguay  ...    26000.0                   1.0
# 407                     England  ...   114580.0                   0.0
# 409                     Belgium  ...   114500.0                   0.0
# 411                  Germany FR  ...   114600.0                   1.0
# 412                    Cameroon  ...    73780.0                   0.0
# 424                Soviet Union  ...    55759.0                   1.0
# 436                     Romania  ...    52733.0                   0.0
# 474                      Greece  ...    54456.0                   2.0
# 486                     Nigeria  ...    54453.0                   2.0
# 499                    Bulgaria  ...    63998.0                   0.0
# 526                       Japan  ...    33500.0                   1.0
# 544                     Jamaica  ...    45500.0                   1.0
# 561                     Croatia  ...    31800.0                   1.0
# 571                     England  ...    30600.0                   0.0
# 584                     Nigeria  ...    34050.0                   0.0
# 601                     England  ...    35927.0                   0.0
# 648               C�te d'Ivoire  ...    49480.0                   2.0
# 664   rn">Serbia and Montenegro  ...    52000.0                   3.0
# 693                      Mexico  ...    43000.0                   0.0
# 711                     Nigeria  ...    55686.0                   1.0
# 725              Korea Republic  ...    82174.0                   2.0
# 759                      Mexico  ...    84377.0                   2.0
# 766                     Germany  ...    64100.0                   0.0
# 782  rn">Bosnia and Herzegovina  ...    74738.0                   1.0
# 798                     IR Iran  ...    57698.0                   0.0
# 831                     Belgium  ...    68551.0                   1.0
# 834                 Switzerland  ...    63255.0                   0.0
# 842                 Switzerland  ...    63255.0                   0.0
# 846                     Belgium  ...    68551.0                   1.0
#
#      Half-time Away Goals                             Referee  \
# 4                     0.0                 REGO Gilberto (BRA)
# 10                    1.0                SAUCEDO Ulises (BOL)
# 14                    1.0                 LANGENUS Jean (BEL)
# 15                    0.0                 LANGENUS Jean (BEL)
# 103                   2.0                LEAFE Reginald (ENG)
# 115                   1.0                   AHLNER Sten (SWE)
# 138                   0.0              GARDEAZABAL Juan (ESP)
# 174                   0.0            RUMENTCHEV Dimitar (BUL)
# 185                   0.0      FERNANDES CAMPOS Joaquim (POR)
# 247                   1.0                 KAZAKOV Pavel (URS)
# 253                   0.0          SANCHEZ IBANEZ Pablo (ESP)
# 260                   1.0                  LORAUX Vital (BEL)
# 266                   1.0                   TAYLOR John (ENG)
# 273                   1.0               GARRIDO Antonio (POR)
# 281                   0.0                   DUBACH Jean (SUI)
# 297                   0.0                  ERIKSSON Ulf (SWE)
# 301                   0.0                PALOTAI Karoly (HUN)
# 305                   0.0                  WURTZ Robert (FRA)
# 307                   0.0                GONELLA Sergio (ITA)
# 308                   0.0              CHRISTOV Vojtech (TCH)
# 321                   0.0                LACARNE Belaid (ALG)
# 336                   0.0                BARRANCOS Luis (BOL)
# 350                   1.0           RUBIO VAZQUEZ Mario (MEX)
# 364                   0.0    SANCHEZ ARMINIO Victoriano (ESP)
# 387                   0.0            ULLOA MORERA Berny (CRC)
# 398                   0.0                 AGNOLIN Luigi (ITA)
# 407                   0.0                 BENNACEUR Ali (TUN)
# 409                   0.0       MARQUEZ RAMIREZ Antonio (MEX)
# 411                   0.0          ARPPI FILHO Romualdo (BRA)
# 412                   0.0                VAUTROT Michel (FRA)
# 424                   0.0              FREDRIKSSON Erik (SWE)
# 436                   0.0  SILVA VALENTE Carlos Alberto (POR)
# 474                   0.0                ANGELES Arturo (USA)
# 486                   1.0                   KARLSSON Bo (SWE)
# 499                   0.0                   JOUINI Neji (TUN)
# 526                   0.0            VAN DER ENDE Mario (NED)
# 544                   0.0                 PEDERSEN Rune (NOR)
# 561                   0.0                  BELQOLA Said (MAR)
# 571                   0.0            NIELSEN Kim Milton (DEN)
# 584                   0.0              VEISSIERE Gilles (FRA)
# 601                   1.0             COLLINA Pierluigi (ITA)
# 648                   0.0            DE BLEECKERE Frank (BEL)
# 664                   0.0               ROSETTI Roberto (ITA)
# 693                   0.0               BUSACCA Massimo (SUI)
# 711                   0.0                Wolfgang STARK (GER)
# 725                   1.0            DE BLEECKERE Frank (BEL)
# 759                   0.0               ROSETTI Roberto (ITA)
# 766                   1.0               Ravshan IRMATOV (UZB)
# 782                   0.0                  AGUILAR Joel (SLV)
# 798                   0.0                 MAZIC Milorad (SRB)
# 831                   0.0                Nicola RIZZOLI (ITA)
# 834                   0.0                ERIKSSON Jonas (SWE)
# 842                   0.0                ERIKSSON Jonas (SWE)
# 846                   0.0                Nicola RIZZOLI (ITA)
#
#                            Assistant 1                         Assistant 2  \
# 4                 SAUCEDO Ulises (BOL)          RADULESCU Constantin (ROU)
# 10              ALONSO Gualberto (URU)          RADULESCU Constantin (ROU)
# 14               CRISTOPHE Henry (BEL)                SAUCEDO Ulises (BOL)
# 15                VALLEJO Gaspar (MEX)               WARNKEN Alberto (CHI)
# 103                    HELGE Leo (DEN)                   AHLNER Sten (SWE)
# 115     FERNANDES CAMPOS Joaquim (POR)                     HELGE Leo (DEN)
# 138              BUERGO Fernando (MEX)                MORGAN Raymond (CAN)
# 174    YAMASAKI MALDONADO Arturo (MEX)            ZECEVIC Konstantin (YUG)
# 185                 ZSOLT Istvan (HUN)               BAKHRAMOV Tofik (URS)
# 247             GLOECKNER Rudolf (GDR)                RAINEA Nicolae (ROU)
# 253                KAMEL Mahmoud (EGY)                 NDIAYE Birame (SEN)
# 260                NDIAYE Birame (SEN)                   TAYLOR John (ENG)
# 266                KAMEL Mahmoud (EGY)                  THOMAS Clive (WAL)
# 273               NDIAYE Youssou (SEN)                 PARTRIDGE Pat (ENG)
# 281        OROZCO GUERRERO Cesar (PER)              WINSEMANN Werner (CAN)
# 297                 NAMDAR Jafar (IRN)      GEBREYESUS DIFUE Tesfaye (ERI)
# 301               LINEMAYR Erich (AUT)                  PROKOP Adolf (GDR)
# 305            BIWERSI Ferdinand (GER)                GONELLA Sergio (ITA)
# 307           BARRETO RUIZ Ramon (URU)                LINEMAYR Erich (AUT)
# 308               PALOTAI Karoly (HUN)                 JARGUZ Alojzy (POL)
# 321               VAUTROT Michel (FRA)                RAINEA Nicolae (ROU)
# 336        LAMO CASTILLO Augusto (ESP)                LACARNE Belaid (ALG)
# 350  ARISTIZABAL MURCIA Gilberto (COL)                 CASTRO Gaston (CHI)
# 364         GONZALEZ ROA Gabriel (PAR)            DIAZ PALACIO Jesus (COL)
# 387         ARPPI FILHO Romualdo (BRA)      MARTINEZ BAZAN Jose Luis (URU)
# 398              COURTNEY George (ENG)  SILVA VALENTE Carlos Alberto (POR)
# 407           ULLOA MORERA Berny (CRC)                DOTCHEV Bogdan (BUL)
# 409         MENDEZ MOLINA Romulo (GUA)  SILVA VALENTE Carlos Alberto (POR)
# 411             FREDRIKSSON Erik (SWE)            ULLOA MORERA Berny (CRC)
# 412                MAURO Vincent (USA)            LISTKIEWICZ Michal (POL)
# 424            RAMIZ WRIGHT Jose (BRA)               AL SHARIF Jamal (SYR)
# 436           ULLOA MORERA Berny (CRC)                  LONGHI Carlo (ITA)
# 474                PARK Hae-Yong (KOR)                   DOLSTRA Jan (NED)
# 486              EVERSTIG Mikael (SWE)                   MATTHYS Luc (BEL)
# 499              YLI-KARRO Tapio (FIN)      RHARIB El Jilali Mohamed (MAR)
# 526          VAN DEN BROECK Marc (BEL)                   FOLEY Eddie (IRL)
# 544               NILSSON Mikael (SWE)                MAZZEI Gennaro (ITA)
# 561     SOLDATOS Aristidis Chris (RSA)                MANSRI Mohamed (TUN)
# 571            ABDUL HAMID Halim (MAS)             AL MUSAWI Mohamed (OMA)
# 584             ARNAULT Frederic (FRA)                MUELLER Heiner (GER)
# 601               VERGARA Hector (CAN)                 SAEED Mohamed (MDV)
# 648                HERMANS Peter (BEL)                VROMANS Walter (BEL)
# 664            COPELLI Cristiano (ITA)           STAGNOLI Alessandro (ITA)
# 693           BURAGINA Francesco (SUI)                ARNET Matthias (SUI)
# 711           SALVER Jan-Hendrik (GER)                   PICKEL Mike (GER)
# 725                HERMANS Peter (BEL)                VROMANS Walter (BEL)
# 759               CALCAGNO Paolo (ITA)               AYROLDI Stefano (ITA)
# 766               ILYASOV Rafael (UZB)            KOCHKAROV Bakhadyr (KGZ)
# 782               TORRES William (SLV)                    ZUMBA Juan (SLV)
# 798               RISTIC Milovan (SRB)            DJURDJEVIC Dalibor (SRB)
# 831              Renato FAVERANI (ITA)                Andrea STEFANI (ITA)
# 834            KLASENIUS Mathias (SWE)               WARNMARK Daniel (SWE)
# 842            KLASENIUS Mathias (SWE)               WARNMARK Daniel (SWE)
# 846              Renato FAVERANI (ITA)                Andrea STEFANI (ITA)
#
#         RoundID      MatchID  Home Team Initials Away Team Initials
# 4         201.0       1085.0                 ARG                FRA
# 10        201.0       1086.0                 ARG                MEX
# 14        201.0       1084.0                 ARG                CHI
# 15        202.0       1088.0                 ARG                USA
# 103       220.0       1323.0                 ARG                FRG
# 115       220.0       1324.0                 ARG                NIR
# 138       231.0       1447.0                 ARG                BUL
# 174       238.0       1578.0                 ARG                ESP
# 185       238.0       1582.0                 ARG                SUI
# 247       262.0       1949.0                 ARG                ITA
# 253       262.0       1947.0                 ARG                HAI
# 260       263.0       1945.0                 ARG                BRA
# 266       263.0       1946.0                 ARG                GDR
# 273       278.0       2199.0                 ARG                HUN
# 281       278.0       2197.0                 ARG                FRA
# 297       279.0       2202.0                 ARG                POL
# 301       279.0       2196.0                 ARG                BRA
# 305       279.0       2201.0                 ARG                PER
# 307       639.0       2198.0                 ARG                NED
# 308       293.0        749.0                 ARG                BEL
# 321       293.0        752.0                 ARG                HUN
# 336       293.0        751.0                 ARG                SLV
# 350       294.0        750.0                 ARG                BRA
# 364       308.0        395.0                 ARG                KOR
# 387       308.0        389.0                 ARG                BUL
# 398       309.0        398.0                 ARG                URU
# 407       714.0        392.0                 ARG                ENG
# 409      3469.0        388.0                 ARG                BEL
# 411      3467.0        393.0                 ARG                FRG
# 412       322.0         26.0                 ARG                CMR
# 424       322.0         30.0                 ARG                URS
# 436       322.0         29.0                 ARG                ROU
# 474       337.0       3059.0                 ARG                GRE
# 486       337.0       3071.0                 ARG                NGA
# 499       337.0       3084.0                 ARG                BUL
# 526      1014.0       8734.0                 ARG                JPN
# 544      1014.0       8752.0                 ARG                JAM
# 561      1014.0       8772.0                 ARG                CRO
# 571      1024.0       8779.0                 ARG                ENG
# 584  43950100.0   43950007.0                 ARG                NGA
# 601  43950100.0   43950023.0                 ARG                ENG
# 648  97410100.0   97410005.0                 ARG                CIV
# 664  97410100.0   97410021.0                 ARG                SCG
# 693  97410200.0   97410050.0                 ARG                MEX
# 711    249722.0  300061460.0                 ARG                NGA
# 725    249722.0  300061458.0                 ARG                KOR
# 759    249717.0  300061502.0                 ARG                MEX
# 766    249718.0  300061505.0                 ARG                GER
# 782    255931.0  300186477.0                 ARG                BIH
# 798    255931.0  300186466.0                 ARG                IRN
# 831    255953.0  300186504.0                 ARG                BEL
# 834    255951.0  300186503.0                 ARG                SUI
# 842    255951.0  300186503.0                 ARG                SUI
# 846    255953.0  300186504.0                 ARG                BEL
#
# [54 rows x 21 columns]

# %% [markdown]
# ## Woman dataset cleanup

# %% [markdown]
# Change stage names:

# %%
women_worldcup_results = women_worldcup_results.replace(np.nan, '', regex=True)
women_worldcup_results['Stage'] = women_worldcup_results['Stage'].apply(lambda x: 'Group A' if (x == 'group-a') else x )
women_worldcup_results['Stage'] = women_worldcup_results['Stage'].apply(lambda x: 'Group B' if (x == 'group-b') else x )
women_worldcup_results['Stage'] = women_worldcup_results['Stage'].apply(lambda x: 'Group C' if (x == 'group-c') else x )
women_worldcup_results['Stage'] = women_worldcup_results['Stage'].apply(lambda x: 'Group D' if (x == 'group-d') else x )
women_worldcup_results['Stage'] = women_worldcup_results['Stage'].apply(lambda x: 'Group E' if (x == 'group-e') else x )
women_worldcup_results['Stage'] = women_worldcup_results['Stage'].apply(lambda x: 'Group F' if (x == 'group-f') else x )
women_worldcup_results['Stage'] = women_worldcup_results['Stage'].apply(lambda x: 'Final' if (x == 'final') else x )
women_worldcup_results['Stage'] = women_worldcup_results['Stage'].apply(lambda x: 'Quarter-finals' if (x == 'quarter-finals') else x )
women_worldcup_results['Stage'] = women_worldcup_results['Stage'].apply(lambda x: 'Semi-finals' if (x == 'semi-finals') else x )
women_worldcup_results['Stage'] = women_worldcup_results['Stage'].apply(lambda x: 'Third place' if (x == 'third-place') else x )
women_worldcup_results['Stage'] = women_worldcup_results['Stage'].apply(lambda x: 'Round of 16' if (x == 'round-16') else x )

# %% [markdown]
# Separate score to each side:

# %%
women_worldcup_results['Score'] = women_worldcup_results['Score'].apply(lambda x: x.replace('-','–'))

women_worldcup_results['Home Team Goals'] = women_worldcup_results['Score'].apply(lambda x: x.split('–')[0])
women_worldcup_results['Away Team Goals'] = women_worldcup_results['Score'].apply(lambda x: x.split('–')[1])

# %%
women_worldcup_results = women_worldcup_results[['Year','Stage','Home Team Name','Home Team Goals','Away Team Goals','Away Team Name','Win conditions']]
women_worldcup_results.insert(1, 'Gender', 'F')

# %%
women_worldcup_results.head()
# Out:
#    Year Gender    Stage Home Team Name Home Team Goals Away Team Goals  \
# 0  1991      F  Group A       China PR               4               0
# 1  1991      F  Group A        Denmark               3               0
# 2  1991      F  Group A         Norway               4               0
# 3  1991      F  Group A       China PR               2               2
# 4  1991      F  Group A       China PR               4               1
#
#   Away Team Name Win conditions
# 0         Norway
# 1    New Zealand
# 2    New Zealand
# 3        Denmark
# 4    New Zealand

# %% [markdown]
# ## Append both datasets

# %%
world_cup_results = men_worldcup_results.append(women_worldcup_results)
world_cup_results =world_cup_results.replace(np.nan, '', regex=True)

# %% [markdown]
# Clean nan and turn year to int:

# %%
world_cup_results =world_cup_results.replace(np.nan, '', regex=True)

world_cup_results['Year'] = world_cup_results['Year'].apply(lambda x: int(x))

# %% [markdown]
# Clean different country names:

# %%
world_cup_results['Home Team Name'] = world_cup_results['Home Team Name'].apply(lambda x : 'Germany' if (x == 'German DR' or x == 'Germany FR') else x )
world_cup_results['Home Team Name'] = world_cup_results['Home Team Name'].apply(lambda x : 'Iran' if (x == 'IR Iran') else x )

# %% [markdown]
# # Play a game!

# %%
men = world_cup_results[world_cup_results['Gender'] == 'M']
women = world_cup_results[world_cup_results['Gender'] == 'F']

# %%
team_1 = input("Team 1")
team_2 = input("Team 2")
# Out:
# Team 1Argentina
# Team 2Brazil

# %%
condition_1 = men['Home Team Name'] == team_1
condition_2 = men['Away Team Name'] == team_2
condition_3 = men['Home Team Name'] == team_2
condition_4 = men['Away Team Name'] == team_1

# %%
men[condition_1 & condition_2 | condition_3 & condition_4 ]
# Out:
#      Year              Datetime Gender        Stage  \
# 260  1974  30 Jun 1974 - 16:00       M      Group A
# 301  1978  18 Jun 1978 - 19:15       M      Group B
# 350  1982  02 Jul 1982 - 17:15       M      Group 3
# 450  1990  24 Jun 1990 - 17:00       M  Round of 16
#
#                                          Stadium        City Home Team Name  \
# 260                         Niedersachsenstadion    Hanover       Argentina
# 301  Arroyito - Estadio Dr. Lisandro de la Torre    Rosario       Argentina
# 350                                       Sarria  Barcelona       Argentina
# 450                            Stadio delle Alpi      Turin          Brazil
#
#     Home Team Goals Away Team Goals Away Team Name  ... Attendance  \
# 260               1               2         Brazil  ...      39400
# 301               0               0         Brazil  ...      37326
# 350               1               3         Brazil  ...      44000
# 450               0               1      Argentina  ...      61381
#
#     Half-time Home Goals Half-time Away Goals                    Referee  \
# 260                    1                    1         LORAUX Vital (BEL)
# 301                    0                    0       PALOTAI Karoly (HUN)
# 350                    0                    1  RUBIO VAZQUEZ Mario (MEX)
# 450                    0                    0         QUINIOU Joel (FRA)
#
#                            Assistant 1               Assistant 2 RoundID  \
# 260                NDIAYE Birame (SEN)         TAYLOR John (ENG)     263
# 301               LINEMAYR Erich (AUT)        PROKOP Adolf (GDR)     279
# 350  ARISTIZABAL MURCIA Gilberto (COL)       CASTRO Gaston (CHI)     294
# 450                SPIRIN Alexey (RUS)  PAIRETTO Pierluigi (ITA)     323
#
#     MatchID Home Team Initials Away Team Initials
# 260    1945                ARG                BRA
# 301    2196                ARG                BRA
# 350     750                ARG                BRA
# 450      25                BRA                ARG
#
# [4 rows x 21 columns]
